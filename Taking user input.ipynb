# %% [markdown]
# # `input()` method takes input from the user

# %%
number = input("Enter a Number :")
print(number)
# Out:
# Enter a Number :4
# 4

# %%
x=(input("Enter any number of your choice:"))
y=(input("Enter any number of your choice:"))
print("the sum is", x+y)
# Out:
# Enter any number of your choice:4
# Enter any number of your choice:4
# the sum is 44

# %%
x=(input("Enter any number of your choice:"))
type(x) #by default input takes any value in string we want to convert it into int

# %% [markdown]
# # Type casting
#
# User casts data types explicitly from one to another

# %%
x=int(input("Enter any number of your choice:"))
type(x)
# Out:
# Enter any number of your choice:5
# int

# %% [markdown]
# ` What are modules and packages in Python?`

# %% [markdown]
# ![Screen%20Shot%202023-06-19%20at%208.10.45%20AM.png](attachment:Screen%20Shot%202023-06-19%20at%208.10.45%20AM.png)
#
#
# to insert a photo in markdown copy a image and paste it in markdown

# %% [markdown]
# # LaTeX
#
# starts with $ and ends with $(dollar)
#
# used for writing mathematical formulae , cv etc.
#
# * written in markdown
# * we cannot give space after and before $
#
# for vol of cube the latex is
#
# $volume(v) = \frac{4}{3} \pi r^3$
#
# ![Screen%20Shot%202023-06-19%20at%208.34.17%20AM.png](attachment:Screen%20Shot%202023-06-19%20at%208.34.17%20AM.png)

# %% [markdown]
#  # operator precedence (Priority) in python
#
#  ![Screen%20Shot%202023-06-19%20at%208.38.42%20AM.png](attachment:Screen%20Shot%202023-06-19%20at%208.38.42%20AM.png)

# %%
2 ** 2 ** 3 # right to left ~~ exponentiation operator ko lagi matra || but for others like addition left to right
# Out:
# 256
