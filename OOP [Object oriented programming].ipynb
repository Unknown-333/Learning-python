# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hello = 'str'
print(type(hello))
# Out:
# <class 'str'>

# %% [markdown]
# #  Python class

# %%
# creating empty class
class Mammal:
    pass

# %%
# create empty class of person
class Person:
    pass

# %% [markdown]
# # Creating object from class

# %%
class Mammal:
    pass

human = Mammal()
print(type(human)) # __main__ => entry point of python code || double underscore vaneko dunders Eg __str__
# Out:
# <class '__main__.Mammal'>

# %%
class Mammal:
    pass

if __name__ == '__main__':
    human = Mammal()
    print(type(human))
# Out:
# <class '__main__.Mammal'>

# %% [markdown]
#  # Creating multiple objects from a class

# %%
class Mammal:
    pass

human = Mammal() # human is one object of Mammal class
cow = Mammal()  # cow is another object of Mammal class
dog = Mammal()  # dog is another object of Mammal class

# %% [markdown]
# # class vs object
#
# * class is a blueprint to create an object
# * an object is a instance of a class

# %% [markdown]
# # Class attribute vs Object attribute

# %%
class Mammal:
    has_hair = True #class attribute
    no_of_eyes = 2

# %%
human = Mammal()
human.has_hair
# Out:
# True

# %%
cow = Mammal()
cow.has_hair
# Out:
# True

# %%
cow.no_of_eyes
# Out:
# 2

# %% [markdown]
# # initializing object attribute

# %%
class Mammal:
    has_hair = True
    
    def __init__(self): # initializes object atribute
        pass

# %% [markdown]
# # Initialize no_of_legs as object attribute

# %%
class Mammal:
    has_hair = True
    
    def __init__(self, no_of_legs):
        self.no_of_legs = no_of_legs

# %%
human = Mammal()
# Out:
# <class '__main__.Mammal'>

# %%
human = Mammal(no_of_legs = 2)

# %%
human.has_hair
# Out:
# True

# %%
human.no_of_legs
# Out:
# 2

# %%
cow = Mammal(no_of_legs = 4)

# %%
cow.has_hair
# Out:
# True

# %%
cow.no_of_legs
# Out:
# 4

# %%
# What is self => self is an object
class Mammal:
    def __init__(self): # __init__ ==> initializes object attribute Eg: kati ota khutta ho obj(cow) ko
        print(type(self))

# %%
cow = Mammal()
# Out:
# <class '__main__.Mammal'>

# %%
print(type(cow))
# Out:
# <class '__main__.Mammal'>

# %% [markdown]
# * The self parameter is a refrence to the current instance of the class, and is used to access variables that belong to the class.
# * It does not have to be names self, you can call it whatever you like, but it has to be the first parameter of any function in the class.
#
#
# * All classes have a function called `__init()__`, which is always executed when the class is being initialized.
# * Use the `__init__()` function to assign values to object properties, or other operations that are necessary to do when the object is being created.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        
p1= Person("Aayush", 17)

print(p1.name)
print(p1.age)
# Out:
# Aayush
# 17

# %% [markdown]
# # __init__() is not a constructor because self is and object passed to __init__ method it means object is already created before we call __init__() method

# %% [markdown]
#  __new__() and __init__() work together in constructing objects __new__() to create it, and __init__() to cusromize it , no non-None value may be returned by __init__(); doing so will cause a TypeError to be raised at runtime

# %% [markdown]
# # init() should return None

# %%
class Person:
    def __init__(self):
        return 5

# %%
Person()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 Person()
#
# TypeError: __init__() should return None, not 'int'

# %% [markdown]
# # user defined function in class

# %%
import math
class circle:
    def __init__(self, radius):
        self.r = radius
        
    def area(self):
        return math.pi * self.r ** 2

# %%
c1 = circle(radius = 5)

# %%
c1.area()
# Out:
# 78.53981633974483

# %%
c2 = circle(radius = 9)

# %%
c2.area()
# Out:
# 254.46900494077323

# %%
c3 = circle(r = 7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 c3 = circle(r = 7)
#
# TypeError: circle.__init__() got an unexpected keyword argument 'r'

# %%
class rec:
    
    def __init__(self, length, breadth):
        self.l = length
        self.b = breadth
        
    def area(self):
        return self.l * self.b
    
    def perimeter(self):
        return 2*(self.l + self.b)

length = int(input("Enter the length of your choice: "))
breadth = int(input("Enter the breadth of your choice: "))

rectangle = rec(length = length , breadth = breadth )
area, perimeter = rectangle.area(), rectangle.perimeter()
print(f"The area of rectangle is : {area}")
print(f"The perimeter of rectangle is : {perimeter}")
# Out:
# Enter the length of your choice: 10
# Enter the breadth of your choice: 10
# The area of rectangle is : 100
# The perimeter of rectangle is : 40

# %%
a1 = rec(length = 5, breadth = 5)

# %%
a1.area()
# Out:
# (25, 20)

# %%
rectangle = rec(length = 10, breadth = 10)
area, perimeter = rectangle.area()
print("Area :", area)
print("Perimeter :",perimeter)
# Out:
# Area : 100
# Perimeter : 40
